# %% [markdown]
# # Iris Classification Exercise
#
# ### Aim: classify iris species using sepal and petal measurements.
#
# The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# Warning: this is an extremelly simple problem, expect close to 100% accuracy.

# %%
# Start by loading the dataset
import pandas as pd

url_data  = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"]

df = pd.read_csv(url_data, header=None, names=columns, skipinitialspace=True)
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
# STEP1: Create training data: X and y variables

# %%
# STEP2: Partition data into training and test sets (80% train, 20% test)
# Use train_test_split from sklearn.model_selection

# %%
# STEP3: Create ML model from scikit-learn
# Suggestion: use k-Nearest Neighbors classifier 
# from sklearn.neighbors import KNeighborsClassifier

# %%
# STEP4: Fit model to training data

# %%
# STEP5: Make predictions on training and test data

# %%
# STEP6: Print accuracies for training and test sets
# Accuracies should be above 90%
# Out:
# Train accuracy: 0.95
# Test accuracy: 1.0
