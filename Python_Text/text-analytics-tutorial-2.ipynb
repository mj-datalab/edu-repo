# %% [markdown]
# # Clustering text documents using k-means

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import silhouette_score
from scipy.stats import randint
import numpy as np

# -------------------------------------
# 1) Load only the requested categories
# -------------------------------------
categories = [
    "alt.atheism",
    "talk.religion.misc",
    "comp.graphics",
    "sci.space",
]

data = fetch_20newsgroups(
    subset="all",
    categories=categories,
    remove=("headers", "footers", "quotes")
)
X_text = data.data

# -------------------------------------
# 2) Pipeline: TF-IDF ("tfidf") → K-Means ("clusterer")
# -------------------------------------

# -------------------------------------
# 3) Silhouette scorer
# -------------------------------------
def silhouette_scorer(estimator, X):
    X_tfidf = estimator.named_steps["tfidf"].transform(X)
    labels = estimator.named_steps["clusterer"].predict(X_tfidf)

    if len(set(labels)) < 2:
        return -1.0

    return silhouette_score(X_tfidf, labels, metric="cosine")

# -------------------------------------
# 4) Search space (param_dist)
# -------------------------------------

# -------------------------------------
# 5) Randomized Search (use scoring=silhouette_scorer)
# -------------------------------------

# -------------------------------------
# 6) Compute full-data silhouette
# -------------------------------------

# -------------------------------------
# 7) Top words per cluster
# -------------------------------------
tfidf = best_model.named_steps["tfidf"]
kmeans = best_model.named_steps["clusterer"]

feature_names = np.array(tfidf.get_feature_names_out())
centroids = kmeans.cluster_centers_

n_top = 15  # number of top words to show per cluster

print("\n==============================")
print(" Top words per cluster")
print("==============================")

for cluster_idx in range(kmeans.n_clusters):
    centroid = centroids[cluster_idx]
    top_idx = centroid.argsort()[::-1][:n_top]
    top_terms = feature_names[top_idx]
    print(f"\nCluster {cluster_idx}:")
    print(", ".join(top_terms))
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
#
# Best CV silhouette: 0.006209203663074539
# Best parameters:
#   clusterer__n_clusters: 5
#   tfidf__max_df: 0.5
#   tfidf__min_df: 2
#   tfidf__ngram_range: (1, 1)
#
# Silhouette on full data: 0.0048
#
# ==============================
#  Top words per cluster
# ==============================
#
# Cluster 0:
# god, jesus, bible, believe, people, christian, say, don, religion, does, faith, belief, think, christians, atheism
#
# Cluster 1:
# space, nasa, launch, shuttle, moon, orbit, like, mission, earth, just, think, cost, don, people, hst
#
# Cluster 2:
# just, don, think, like, people, know, does, say, time, did, good, ve, right, said, question
#
# Cluster 3:
# graphics, software, comp, computer, 3d, edu, image, available, ftp, information, pc, data, package, email, like
#
# Cluster 4:
# thanks, file, files, format, image, gif, know, program, looking, advance, hi, help, does, windows, need
